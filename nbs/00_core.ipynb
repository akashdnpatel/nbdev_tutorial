# %% [markdown]
# # Initial Template
#
# > This is basic notebook to understand nbdev flow for development

# %%
#| default_exp core

# %%
#| hide
from nbdev.showdoc import *
import pandas as pd

# %%
#| export
from nbdev.showdoc import *
import pandas as pd

# %%
#| export
def prepare_dataframes():
    data = [10,20,30,40,10,20,30,40,50]
    df = pd.DataFrame(data, columns=['Numbers'])
    
    data1 = [12,21,31,12,13,54,32,21,12]
    df1 = pd.DataFrame(data1, columns=['Numbers1'])
    return df, df1

# %%
#| export
df, df1 = prepare_dataframes()

# %% [markdown]
# ## Visualisation 1

# %%
df.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
#| export
df2 = pd.concat([df,df1], axis=1)
df2
# Out:
#    Numbers  Numbers1
# 0       10        12
# 1       20        21
# 2       30        31
# 3       40        12
# 4       10        13
# 5       20        54
# 6       30        32
# 7       40        21
# 8       50        12

# %% [markdown]
# ## Visualisation 2

# %%
df2.plot.scatter(x='Numbers', y='Numbers1')
# Out:
# <AxesSubplot: xlabel='Numbers', ylabel='Numbers1'>

# %%
#| hide
import nbdev; nbdev.nbdev_export()
